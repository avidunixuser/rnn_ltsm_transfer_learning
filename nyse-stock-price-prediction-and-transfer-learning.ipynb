# %% [markdown]
# # Aim :
# ## Predicting Stock prices of Apple, Google and Amazon
# Our first aim is to predict the next day closing stock price for Apple, Google and Amazon. **For this we will train the model that learns from the data of all the 3 companies.**
# ## Experiment with Transfer Learning
# After this we will see if we can design a model that only learns from the data of a single company (**Google**), but predicts well for the other two (**Apple and Amazon**) also. This is called **Transfer Learning**.

# %%
import numpy as np
import pandas
import seaborn
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pandas.read_csv('/content/drive/MyDrive/Colab Notebooks/stock prediction/prices.csv')

# %%
df.head()
# Out:
#                   date symbol        open       close         low        high  \
# 0  2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %%
print(df.shape)
# Out:
# (851264, 7)

# %% [markdown]
# # Filtering out the dataset
# Our aim will be limited to predicting **Apple, Google and Amazon stocks**. Ticker symbol for the respective companies are AAPL, GOOGL and AMZN.

# %%
print(df[df['symbol'] == 'AAPL'].shape)
print(df[df['symbol'] =='GOOGL'].shape)
print(df[df['symbol'] == 'AMZN'].shape)
# Out:
# (1762, 7)
# (1762, 7)
# (1762, 7)

# %%
main_df = df[(df['symbol'] == 'AAPL') | (df['symbol'] == 'GOOGL') | (df['symbol'] == 'AMZN')].reset_index(drop = True)

# %%
print('Number of missing values : ' + str(main_df.isna().sum().sum()))
# Out:
# Number of missing values : 0

# %%
main_df.head(9)
# Out:
#          date symbol        open       close         low        high  \
# 0  2010-01-04   AAPL  213.429998  214.009998  212.380001  214.499996
# 1  2010-01-04   AMZN  136.250000  133.899994  133.139999  136.610001
# 2  2010-01-04  GOOGL  626.950006  626.750011  624.240011  629.510005
# 3  2010-01-05   AAPL  214.599998  214.379993  213.249994  215.589994
# 4  2010-01-05   AMZN  133.429993  134.690002  131.809998  135.479996
# 5  2010-01-05  GOOGL  627.180001  623.990017  621.540016  627.839984
# 6  2010-01-06   AAPL  214.379993  210.969995  210.750004  215.230000
# 7  2010-01-06   AMZN  134.600006  132.250000  131.649994  134.729996
# 8  2010-01-06  GOOGL  625.860033  608.260035  606.360021  625.860033
#
#         volume
# 0  123432400.0
# 1    7599900.0
# 2    3908400.0
# 3  150476200.0
# 4    8851900.0
# 5    6003300.0
# 6  138040000.0
# 7    7178800.0
# 8    7949400.0

# %% [markdown]
# # Starting and ending duration

# %%
print(main_df['date'].min())
print(main_df['date'].max())
# Out:
# 2010-01-04
# 2016-12-30

# %% [markdown]
# So we have data from **4th of January, 2010** to **30th of December, 2016**

# %% [markdown]
# # One hot encode the symbols

# %%
main_df = pandas.get_dummies(main_df, columns = ['symbol'])

# %%
main_df.head(9)
# Out:
#          date        open       close         low        high       volume  \
# 0  2010-01-04  213.429998  214.009998  212.380001  214.499996  123432400.0
# 1  2010-01-04  136.250000  133.899994  133.139999  136.610001    7599900.0
# 2  2010-01-04  626.950006  626.750011  624.240011  629.510005    3908400.0
# 3  2010-01-05  214.599998  214.379993  213.249994  215.589994  150476200.0
# 4  2010-01-05  133.429993  134.690002  131.809998  135.479996    8851900.0
# 5  2010-01-05  627.180001  623.990017  621.540016  627.839984    6003300.0
# 6  2010-01-06  214.379993  210.969995  210.750004  215.230000  138040000.0
# 7  2010-01-06  134.600006  132.250000  131.649994  134.729996    7178800.0
# 8  2010-01-06  625.860033  608.260035  606.360021  625.860033    7949400.0
#
#    symbol_AAPL  symbol_AMZN  symbol_GOOGL
# 0            1            0             0
# 1            0            1             0
# 2            0            0             1
# 3            1            0             0
# 4            0            1             0
# 5            0            0             1
# 6            1            0             0
# 7            0            1             0
# 8            0            0             1

# %%
from tabulate import tabulate
info = [[col, main_df[col].count(), main_df[col].max(), main_df[col].min()] for col in main_df.columns]
print(tabulate(info, headers = ['Feature', 'Count', 'Maximum', 'Minimum'], tablefmt= 'orgtbl'))
# Out:
# | Feature      |   Count | Maximum     | Minimum    |
# |--------------+---------+-------------+------------|
# | date         |    5286 | 2016-12-30  | 2010-01-04 |
# | open         |    5286 | 1226.800064 | 90.0       |
# | close        |    5286 | 1220.169982 | 90.279999  |
# | low          |    5286 | 1218.60002  | 89.470001  |
# | high         |    5286 | 1228.880013 | 90.699997  |
# | volume       |    5286 | 470249500.0 | 520600.0   |
# | symbol_AAPL  |    5286 | 1           | 0          |
# | symbol_AMZN  |    5286 | 1           | 0          |
# | symbol_GOOGL |    5286 | 1           | 0          |

# %% [markdown]
# # Exploratory Data Analysis

# %%
main_df = main_df.drop(['date'], axis = 1)

# %%
seaborn.pairplot(main_df.drop(['symbol_AAPL', 'symbol_AMZN', 'symbol_GOOGL'], axis = 1))

# %%
plt.figure(figsize = (15,15))
mat = main_df.drop(['symbol_AAPL', 'symbol_AMZN', 'symbol_GOOGL'], axis = 1).corr()
seaborn.heatmap(mat, annot = True, square = True)

# %%
info = ['open', 'close', 'low', 'high', 'volume']

# %%
plt.figure(figsize = (20,10))

for i in range(4) :
    plt.subplot(2,2,i+1)
    
    plt.plot(main_df[main_df['symbol_AAPL'] == 1][info[i]].values)
    plt.plot(main_df[main_df['symbol_GOOGL']== 1][info[i]].values)
    plt.plot(main_df[main_df['symbol_AMZN'] == 1][info[i]].values)
    plt.xlabel('time' )
    plt.ylabel(info[i])
    plt.legend(['Apple', 'Google', 'Amazon'])
    plt.title(info[i] + ' vs time')
plt.show()

# %% [markdown]
# Since open price, low price, and high price are linearly correlated with closing price, only one of them will be selected to feed the model, to avoid overfitting. And the second feature will be **volume traded**.

# %%
info = [[col, main_df[col].count(), main_df[col].max(), main_df[col].min()] for col in main_df.columns]
print(tabulate(info, headers = ['Feature', 'Count', 'Maximum', 'Minimum'], tablefmt = 'orgtbl'))
# Out:
# | Feature      |   Count |       Maximum |   Minimum |
# |--------------+---------+---------------+-----------|
# | open         |    5286 | 1226.8        |     90    |
# | close        |    5286 | 1220.17       |     90.28 |
# | low          |    5286 | 1218.6        |     89.47 |
# | high         |    5286 | 1228.88       |     90.7  |
# | volume       |    5286 |    4.7025e+08 | 520600    |
# | symbol_AAPL  |    5286 |    1          |      0    |
# | symbol_AMZN  |    5286 |    1          |      0    |
# | symbol_GOOGL |    5286 |    1          |      0    |

# %% [markdown]
# # Create the dataset
# We will use past 300 days data to predict future stock prices, 100 days of stock data for each company. We will use three fields, apart from **opening price and volume traded** to symbolize the company to which the data belongs to.

# %%
X = np.array(main_df.drop(['close', 'low', 'high'], axis = 1))
y = np.array(main_df['close'])

# %%
print(X.shape)
print(y.shape)
# Out:
# (5286, 5)
# (5286,)

# %% [markdown]
# # Scaling the columns

# %%
print(X[:3])
# Out:
# [[2.13429998e+02 1.23432400e+08 1.00000000e+00 0.00000000e+00
#   0.00000000e+00]
#  [1.36250000e+02 7.59990000e+06 0.00000000e+00 1.00000000e+00
#   0.00000000e+00]
#  [6.26950006e+02 3.90840000e+06 0.00000000e+00 0.00000000e+00
#   1.00000000e+00]]

# %%
from sklearn.preprocessing import MinMaxScaler
X = MinMaxScaler().fit_transform(X)

# %%
print(X[:3])
# Out:
# [[0.1085767  0.2616654  1.         0.         0.        ]
#  [0.04068437 0.01507103 0.         1.         0.        ]
#  [0.4723346  0.00721225 0.         0.         1.        ]]

# %%
print(y.min())
print(y.max())
# Out:
# 90.279999
# 1220.169982

# %%
temp = MinMaxScaler().fit_transform(np.reshape(y, (len(y),1)))
y = temp.reshape(-1)

# %%
print(y.min())
print(y.max())
# Out:
# 0.0
# 1.0

# %%
print(X.min())
print(X.max())
# Out:
# 0.0
# 1.0

# %%
print(y[3:6])
# Out:
# [0.1098337  0.03930471 0.47235574]

# %% [markdown]
# # Creating the actual time series based numpy array
# An **important** point to note is that we will have three outputs or target labels in y. These are the three closing prices, each for AAPL, AMAZN and GOOGL respectively.

# %%
length = 300                         # 100 days * 3 companies

X_res = []
y_res = []

for i in range(length,len(X)-2) :
    X_res.append(X[i-length:i])      # contains features for past 100 days for 3 companies.
    y_res.append(y[i:i+3])           # the next three closing prices for AAPL, AMZN, GOOGL.

X_res = np.array(X_res)
y_res = np.array(y_res)

# %%
print(X_res.shape)
print(y_res.shape)
# Out:
# (4984, 300, 5)
# (4984, 3)

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test  = train_test_split(X_res, y_res, test_size = 0.3, shuffle = True, random_state = 1)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (3488, 300, 5)
# (3488, 3)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (1496, 300, 5)
# (1496, 3)

# %% [markdown]
# # Model creation
# ### Recurrent Neural Network
# Vanilla neural networks do not have a memory and so they do not take into account any past event for predictions. But this kind of model is poor when working with time series data, where there is dependency accross time. This is where RNN come in. A RNN model has **memory**, which can help in retaining past data and so the predictions are made on those basis.
#
# ### Long Short Term Memory
# Simple RNN models have a **short term memory** and are not able to retain dependencies that occured long before the current state. So LSTM or **long short term memory** is used to retain those dependencies as well, using something called gated units. More info can be found [here](https://medium.com/x8-the-ai-community/understanding-recurrent-neural-networks-in-6-minutes-967ab51b94fe).

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Bidirectional
from keras.layers import BatchNormalization

from keras.layers import Input

# %%
def lstm_layer (hiddenx) :
    
    model = Sequential()
    
    model.add(Bidirectional(LSTM(hiddenx, activation = 'tanh', return_sequences = True)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    return model

# %%
def rnn (hidden1, hidden2, hidden3) :
    
    model = Sequential()
    
    # Input Block
    model.add(Input((length, 5,)))
    
    # LSTM Block
    model.add(lstm_layer(hidden1))
    model.add(lstm_layer(hidden2))
    model.add(Bidirectional(LSTM(hidden3, activation = 'tanh', return_sequences = False)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    # Output Block
    model.add(Dense(3, activation = 'linear'))
    
    model.compile(loss = 'mean_squared_error', optimizer = 'adam')
    return model

# %%
model = rnn(128, 128, 32)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 300, 256)          138240
#
#  sequential_2 (Sequential)   (None, 300, 256)          395264
#
#  bidirectional_2 (Bidirectio  (None, 64)               73984
#  nal)
#
#  batch_normalization_2 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 3)                 195
#
# =================================================================
# Total params: 607,939
# Trainable params: 606,787
# Non-trainable params: 1,152
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint
checkp = ModelCheckpoint('./result_model.h5', monitor = 'val_loss', save_best_only = True, verbose = 1)

# %%
history = model.fit(X_train, y_train, epochs = 1, batch_size = 32, validation_data = (X_test, y_test), callbacks = [checkp])
# Out:
# 109/109 [==============================] - ETA: 0s - loss: 0.6906
# Epoch 1: val_loss improved from inf to 0.05182, saving model to ./result_model.h5
# 109/109 [==============================] - 260s 2s/step - loss: 0.6906 - val_loss: 0.0518

# %%
# plt.figure(figsize = (20, 5))
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.legend(['train_loss', 'validation_loss'])
# plt.xlabel('Epochs')
# plt.ylabel('Losses')
# plt.title('Losses vs Epochs')
# plt.show()

# %%
from keras.models import load_model
model = load_model('./result_model.h5')

# %% [markdown]
# # Prediction

# %%
pred = model.predict(X_test)

# %%
print(pred.shape)
# Out:
# (1496, 3)

# %% [markdown]
# # Performance Metrics
# #### Mean Squared Error
# Sum of squares of differences between actual value and predicted value, divided by the total number of samples. This is an **absolute measure**.
# #### R-squared score
# Basically this metric evaluates how well the model performs compared to predicting mean for every sample. This is a **relative measure**.

# %%
from sklearn.metrics import mean_squared_error, r2_score
print('mean squared error : ' + str(mean_squared_error(y_test, pred)))
print('r2_score : ' + str(r2_score(y_test, pred)))
# Out:
# mean squared error : 0.05181697420165268
# r2_score : -0.12659812130778333

# %% [markdown]
# # Plot the Prediction and Test value

# %%
plt.figure(figsize = (20,15))

plt.subplot(3,1,1)
plt.plot(y_test[:50,0])
plt.plot(pred[:50,0])
plt.xlabel('Period')
plt.ylabel('Closing Prices')
plt.legend(['testing price','predicted price'])
plt.title('Comparison in closing prices for Apple', fontsize = 15)


plt.subplot(3,1,2)
plt.plot(y_test[:50,1])
plt.plot(pred[:50,1])
plt.xlabel('Period')
plt.ylabel('Closing Prices')
plt.legend(['testing price','predicted price'])
plt.title('Comparison in closing prices for Amazon',fontsize = 15)


plt.subplot(3,1,3)
plt.plot(y_test[:50,2])
plt.plot(pred[:50,2])
plt.xlabel('Period')
plt.ylabel('Closing Prices')
plt.legend(['testing price','predicted price'])
plt.title('Comparison in closing prices for Google',fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Comparison in closing prices for Google')

# %% [markdown]
# # Transfer learning

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pandas.read_csv('/content/drive/MyDrive/Colab Notebooks/stock prediction/prices.csv')

# %%
df.head()
# Out:
#                   date symbol        open       close         low        high  \
# 0  2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %% [markdown]
# # Taking stock price data of Google

# %%
df = df[df['symbol'] == 'GOOGL'].reset_index(drop = True)

# %%
df.head()
# Out:
#          date symbol        open       close         low        high  \
# 0  2010-01-04  GOOGL  626.950006  626.750011  624.240011  629.510005
# 1  2010-01-05  GOOGL  627.180001  623.990017  621.540016  627.839984
# 2  2010-01-06  GOOGL  625.860033  608.260035  606.360021  625.860033
# 3  2010-01-07  GOOGL  609.400008  594.100015  592.649990  609.999993
# 4  2010-01-08  GOOGL  592.000005  602.020005  589.110015  603.250036
#
#        volume
# 0   3908400.0
# 1   6003300.0
# 2   7949400.0
# 3  12815700.0
# 4   9439100.0

# %%
df = df.drop(['symbol'], axis = 1)

# %%
print('Starting date : ' + str(df['date'].min()))
print('Lasting date  : ' + str(df['date'].max()))
# Out:
# Starting date : 2010-01-04
# Lasting date  : 2016-12-30

# %% [markdown]
# So the we have data from **04th January, 2010 to 30th December, 2016**.

# %%
print('Number of missing values : ' + str(df.isna().sum().sum()))
print(df.shape)
# Out:
# Number of missing values : 0
# (1762, 6)

# %% [markdown]
# It has already been observed that features **open, close, low and high** are highly correlated, so we must drop two of them (**low and high**) and **date** column. The other feature will be **volume traded**.

# %%
from tabulate import tabulate

# %%
info = [[col, df[col].count(), df[col].max(), df[col].min()] for col in df.columns]
print(tabulate(info, headers = ['Feature', 'Count', 'Maximum', 'Minimum'], tablefmt = 'orgtbl'))
# Out:
# | Feature   |   Count | Maximum     | Minimum    |
# |-----------+---------+-------------+------------|
# | date      |    1762 | 2016-12-30  | 2010-01-04 |
# | open      |    1762 | 1226.800064 | 438.310006 |
# | close     |    1762 | 1220.169982 | 436.069999 |
# | low       |    1762 | 1218.60002  | 433.629998 |
# | high      |    1762 | 1228.880013 | 442.28     |
# | volume    |    1762 | 29619900.0  | 520600.0   |

# %%
X = np.array(df.drop(['date', 'high', 'low', 'close'], axis = 1))
y = np.array(df['close'])

# %%
print(X.shape)
print(y.shape)
# Out:
# (1762, 2)
# (1762,)

# %% [markdown]
# # Scale

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X = MinMaxScaler().fit_transform(X)

# %%
t = np.reshape(y, (len(y),1))
t = MinMaxScaler().fit_transform(t)
y = t.reshape(-1)

# %%
print(X.max())
print(X.min())
# Out:
# 1.0000000000000002
# 0.0

# %%
print(y.max())
print(y.min())
# Out:
# 1.0
# 0.0

# %% [markdown]
# # Convert to time series data

# %%
length = 300

X_res = []
y_res = []

for i in range(length , len(X)) :
    X_res.append(X[i-length:i])
    y_res.append(y[i])

X_res = np.array(X_res)
y_res = np.array(y_res)

# %%
print(X_res.shape)
print(y_res.shape)
# Out:
# (1462, 300, 2)
# (1462,)

# %% [markdown]
# # Train/test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size = 0.2, random_state = 1)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (1169, 300, 2)
# (1169,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (293, 300, 2)
# (293,)

# %% [markdown]
# # Build the model

# %%
from keras.models import Sequential
from keras.layers import Input
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Bidirectional
from keras.layers import BatchNormalization

# %%
'''
def lstm_layer (hiddenx) :
    
    model = Sequential()
    
    model.add(Bidirectional(LSTM(hiddenx, activation = 'tanh', return_sequences = True)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    return model
'''

def mod (hidden1, hidden2, hidden3) :
    
    model = Sequential()
    
    # Input layer
    model.add(Input((length, 2,)))
    
    # lstm layer
    model.add(lstm_layer(hidden1))
    model.add(lstm_layer(hidden2))
    model.add(Bidirectional(LSTM(hidden3, activation = 'tanh', return_sequences = False)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    # output layer
    model.add(Dense(1, activation = 'linear'))
    
    model.compile(loss = 'mean_squared_error', optimizer = 'adam')
    
    return model

# %%
model = mod(128, 64, 64)
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_4 (Sequential)   (None, 300, 256)          135168
#
#  sequential_5 (Sequential)   (None, 300, 128)          164864
#
#  bidirectional_5 (Bidirectio  (None, 128)              98816
#  nal)
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 399,489
# Trainable params: 398,465
# Non-trainable params: 1,024
# _________________________________________________________________

# %% [markdown]
# # Model training

# %%
from keras.callbacks import ModelCheckpoint
checkp = ModelCheckpoint('./transfer_model.h5', monitor = 'val_loss', verbose = 1, save_best_only = True)

# %%
history = model.fit(X_train, y_train, epochs = 1, batch_size = 32, callbacks = [checkp], validation_data = (X_test, y_test))
# Out:
# 37/37 [==============================] - ETA: 0s - loss: 1.1062
# Epoch 1: val_loss improved from inf to 0.06199, saving model to ./transfer_model.h5
# 37/37 [==============================] - 72s 2s/step - loss: 1.1062 - val_loss: 0.0620

# %%
plt.figure(figsize = (20,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training loss', 'Validation loss'])
plt.xlabel('Epochs')
plt.ylabel('Losses')
plt.title('Losses vs Epochs')
# Out:
# Text(0.5, 1.0, 'Losses vs Epochs')

# %% [markdown]
# # Prediction on test data

# %%
from keras.models import load_model
model = load_model('./transfer_model.h5')

# %%
pred = model.predict(X_test)

# %%
print(pred.shape)
# Out:
# (293, 1)

# %%
pred = pred.reshape(-1)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
print('Mean squared error : ' + str(mean_squared_error(y_test, pred)))
print('r2_score : ' + str(r2_score(y_test, pred)))
# Out:
# Mean squared error : 0.061989417966451674
# r2_score : -0.2873894808854962

# %%
plt.figure(figsize = (20,5))

plt.plot(y_test[:100])
plt.plot(pred[:100])
plt.legend(['Testing values', 'predicted values'])
plt.xlabel('Time Period')
plt.ylabel('Closing prices')
plt.title('Comparison b/w predicted and real closing prices (Google)')
# Out:
# Text(0.5, 1.0, 'Comparison b/w predicted and real closing prices (Google)')

# %% [markdown]
# # Now let's evaluate model's performance on stock data of Amazon and Apple.

# %%
df = pandas.read_csv('/content/drive/MyDrive/Colab Notebooks/stock prediction/prices.csv')

# %%
apple = df[df['symbol'] == 'AAPL'].reset_index(drop = True)
amazn = df[df['symbol'] == 'AMZN'].reset_index(drop = True)

# %%
apple.head()
# Out:
#          date symbol        open       close         low        high  \
# 0  2010-01-04   AAPL  213.429998  214.009998  212.380001  214.499996
# 1  2010-01-05   AAPL  214.599998  214.379993  213.249994  215.589994
# 2  2010-01-06   AAPL  214.379993  210.969995  210.750004  215.230000
# 3  2010-01-07   AAPL  211.750000  210.580000  209.050005  212.000006
# 4  2010-01-08   AAPL  210.299994  211.980005  209.060005  212.000006
#
#         volume
# 0  123432400.0
# 1  150476200.0
# 2  138040000.0
# 3  119282800.0
# 4  111902700.0

# %%
amazn.head()
# Out:
#          date symbol        open       close         low        high  \
# 0  2010-01-04   AMZN  136.250000  133.899994  133.139999  136.610001
# 1  2010-01-05   AMZN  133.429993  134.690002  131.809998  135.479996
# 2  2010-01-06   AMZN  134.600006  132.250000  131.649994  134.729996
# 3  2010-01-07   AMZN  132.009995  130.000000  128.800003  132.320007
# 4  2010-01-08   AMZN  130.559998  133.520004  129.029999  133.679993
#
#        volume
# 0   7599900.0
# 1   8851900.0
# 2   7178800.0
# 3  11030200.0
# 4   9830500.0

# %%
print('Apple,')
print('Number of missing values : ' + str(apple.isna().sum().sum()))
print(apple.shape)

print('Amazon')
print('Number of missing values : ' + str(amazn.isna().sum().sum()))
print(amazn.shape)
# Out:
# Apple,
# Number of missing values : 0
# (1762, 7)
# Amazon
# Number of missing values : 0
# (1762, 7)

# %%
apple = apple.drop(['date', 'symbol'], axis = 1)
amazn = amazn.drop(['date', 'symbol'], axis = 1)

# %%
info = [[col, apple[col].count(), apple[col].max(), apple[col].min()] for col in apple.columns]
print(tabulate(info, headers = ['Feature', 'Count', 'Max', 'Min'], tablefmt = 'orgtbl'))
# Out:
# | Feature   |   Count |          Max |          Min |
# |-----------+---------+--------------+--------------|
# | open      |    1762 | 702.41       | 90           |
# | close     |    1762 | 702.1        | 90.28        |
# | low       |    1762 | 699.57       | 89.47        |
# | high      |    1762 | 705.07       | 90.7         |
# | volume    |    1762 |   4.7025e+08 |  1.14759e+07 |

# %%
info = [[col, amazn[col].count(), amazn[col].max(), amazn[col].min()] for col in amazn.columns]
print(tabulate(info, headers = ['Feature', 'Count', 'Max', 'Min'], tablefmt = 'orgtbl'))
# Out:
# | Feature   |   Count |           Max |       Min |
# |-----------+---------+---------------+-----------|
# | open      |    1762 | 845.79        |    105.93 |
# | close     |    1762 | 844.36        |    108.61 |
# | low       |    1762 | 840.6         |    105.8  |
# | high      |    1762 | 847.21        |    111.29 |
# | volume    |    1762 |   4.24211e+07 | 984400    |

# %% [markdown]
# # Create arrays
# Only use **open price and volume traded**, as other features are correlated with closing price.

# %%
X_apple = np.array(apple.drop(['close', 'low', 'high'], axis = 1))
y_apple = np.array(apple['close'])

X_amazn = np.array(amazn.drop(['close', 'low', 'high'], axis = 1))
y_amazn = np.array(amazn['close'])

# %%
print(X_apple.shape)
print(y_apple.shape)
# Out:
# (1762, 2)
# (1762,)

# %%
print(X_amazn.shape)
print(y_amazn.shape)
# Out:
# (1762, 2)
# (1762,)

# %% [markdown]
# # Scale

# %%
X_apple = MinMaxScaler().fit_transform(X_apple)
X_amazn = MinMaxScaler().fit_transform(X_amazn)

# %%
t = np.reshape(y_apple, (len(y_apple),1))
t = MinMaxScaler().fit_transform(t)
y_apple = t.reshape(-1)

# %%
t = np.reshape(y_amazn, (len(y_amazn),1))
t = MinMaxScaler().fit_transform(t)
y_amazn = t.reshape(-1)

# %%
print(X_apple.max())
print(X_apple.min())
# Out:
# 1.0000000000000002
# 0.0

# %%
print(y_apple.max())
print(y_apple.min())
# Out:
# 1.0
# 0.0

# %%
print(X_amazn.max())
print(X_amazn.min())
# Out:
# 1.0000000000000002
# 0.0

# %%
print(y_amazn.max())
print(y_amazn.min())
# Out:
# 1.0
# 0.0

# %% [markdown]
# # Verify the shapes

# %%
print(X_apple.shape)
print(y_apple.shape)
# Out:
# (1762, 2)
# (1762,)

# %%
print(X_amazn.shape)
print(y_amazn.shape)
# Out:
# (1762, 2)
# (1762,)

# %% [markdown]
# # Create timesteps of size 300

# %%
length = 300

X_res_apple = []
y_res_apple = []

X_res_amazn = []
y_res_amazn = []

# %%
for i in range(length, len(X_apple)) :
    
    X_res_apple.append(X_apple[i-length:i])            # take 300 prior data for apple stock
    y_res_apple.append(y_apple[i])                     # next day closing price
    
    X_res_amazn.append(X_amazn[i-length:i])            # take 300 prior data for Amazonstock
    y_res_amazn.append(y_amazn[i])                     # next day closing price

X_res_apple, y_res_apple = np.array(X_res_apple), np.array(y_res_apple)
X_res_amazn, y_res_amazn = np.array(X_res_amazn), np.array(y_res_amazn)

# %%
print(X_res_apple.shape)
print(y_res_apple.shape)
# Out:
# (1462, 300, 2)
# (1462,)

# %%
print(X_res_amazn.shape)
print(y_res_amazn.shape)
# Out:
# (1462, 300, 2)
# (1462,)

# %%
from sklearn.utils import shuffle

# %%
X_res_apple, y_res_apple = shuffle(X_res_apple, y_res_apple, random_state = 1)
X_res_amazn, y_res_amazn = shuffle(X_res_amazn, y_res_amazn, random_state = 1)

# %% [markdown]
# # Predict for apple stock data

# %%
from keras.models import load_model
model = load_model('./transfer_model.h5')

# %%
for i, layer in enumerate(model.layers) :
    if i < 5 :
        layer.trainable = False

# %%
print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_4 (Sequential)   (None, 300, 256)          135168
#
#  sequential_5 (Sequential)   (None, 300, 128)          164864
#
#  bidirectional_5 (Bidirectio  (None, 128)              98816
#  nal)
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 399,489
# Trainable params: 129
# Non-trainable params: 399,360
# _________________________________________________________________
# None

# %%
X_apple_train, X_apple_test, y_apple_train, y_apple_test = train_test_split(X_res_apple, y_res_apple, test_size = 0.2, random_state = 1)

# %%
print(X_apple_train.shape)
print(y_apple_train.shape)
# Out:
# (1169, 300, 2)
# (1169,)

# %%
print(X_apple_test.shape)
print(y_apple_test.shape)
# Out:
# (293, 300, 2)
# (293,)

# %% [markdown]
# ### Training

# %%
checkp = ModelCheckpoint('./best_apple_model.h5', save_best_only = True, monitor = 'val_loss', verbose = 1)

# %%
history = model.fit(X_apple_train, y_apple_train, epochs = 50, batch_size = 32, validation_data = (X_apple_test, y_apple_test), callbacks = [checkp])
# Out:
# Epoch 1/50
# 37/37 [==============================] - ETA: 0s - loss: 0.5919
# Epoch 1: val_loss improved from inf to 0.15500, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 68s 2s/step - loss: 0.5919 - val_loss: 0.1550
# Epoch 2/50
# 37/37 [==============================] - ETA: 0s - loss: 0.4529
# Epoch 2: val_loss did not improve from 0.15500
# 37/37 [==============================] - 55s 2s/step - loss: 0.4529 - val_loss: 0.1729
# Epoch 3/50
# 37/37 [==============================] - ETA: 0s - loss: 0.4151
# Epoch 3: val_loss improved from 0.15500 to 0.12230, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 57s 2s/step - loss: 0.4151 - val_loss: 0.1223
# Epoch 4/50
# 37/37 [==============================] - ETA: 0s - loss: 0.3516
# Epoch 4: val_loss improved from 0.12230 to 0.10515, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 61s 2s/step - loss: 0.3516 - val_loss: 0.1051
# Epoch 5/50
# 37/37 [==============================] - ETA: 0s - loss: 0.2858
# Epoch 5: val_loss improved from 0.10515 to 0.08549, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 58s 2s/step - loss: 0.2858 - val_loss: 0.0855
# Epoch 6/50
# 37/37 [==============================] - ETA: 0s - loss: 0.2561
# Epoch 6: val_loss did not improve from 0.08549
# 37/37 [==============================] - 55s 2s/step - loss: 0.2561 - val_loss: 0.0917
# Epoch 7/50
# 37/37 [==============================] - ETA: 0s - loss: 0.2371
# Epoch 7: val_loss improved from 0.08549 to 0.06696, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 57s 2s/step - loss: 0.2371 - val_loss: 0.0670
# Epoch 8/50
# 37/37 [==============================] - ETA: 0s - loss: 0.1854
# Epoch 8: val_loss improved from 0.06696 to 0.05805, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 55s 1s/step - loss: 0.1854 - val_loss: 0.0581
# Epoch 9/50
# 37/37 [==============================] - ETA: 0s - loss: 0.1643
# Epoch 9: val_loss improved from 0.05805 to 0.02660, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 57s 2s/step - loss: 0.1643 - val_loss: 0.0266
# Epoch 10/50
# 37/37 [==============================] - ETA: 0s - loss: 0.1686
# Epoch 10: val_loss improved from 0.02660 to 0.01654, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 58s 2s/step - loss: 0.1686 - val_loss: 0.0165
# Epoch 11/50
# 37/37 [==============================] - ETA: 0s - loss: 0.1371
# Epoch 11: val_loss did not improve from 0.01654
# 37/37 [==============================] - 56s 2s/step - loss: 0.1371 - val_loss: 0.0225
# Epoch 12/50
# 37/37 [==============================] - ETA: 0s - loss: 0.1250
# Epoch 12: val_loss improved from 0.01654 to 0.00936, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 58s 2s/step - loss: 0.1250 - val_loss: 0.0094
# Epoch 13/50
# 37/37 [==============================] - ETA: 0s - loss: 0.1097
# Epoch 13: val_loss did not improve from 0.00936
# 37/37 [==============================] - 57s 2s/step - loss: 0.1097 - val_loss: 0.0118
# Epoch 14/50
# 37/37 [==============================] - ETA: 0s - loss: 0.1027
# Epoch 14: val_loss improved from 0.00936 to 0.00392, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 58s 2s/step - loss: 0.1027 - val_loss: 0.0039
# Epoch 15/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0877
# Epoch 15: val_loss did not improve from 0.00392
# 37/37 [==============================] - 56s 2s/step - loss: 0.0877 - val_loss: 0.0095
# Epoch 16/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0732
# Epoch 16: val_loss did not improve from 0.00392
# 37/37 [==============================] - 59s 2s/step - loss: 0.0732 - val_loss: 0.0055
# Epoch 17/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0731
# Epoch 17: val_loss did not improve from 0.00392
# 37/37 [==============================] - 57s 2s/step - loss: 0.0731 - val_loss: 0.0042
# Epoch 18/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0623
# Epoch 18: val_loss improved from 0.00392 to 0.00244, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 58s 2s/step - loss: 0.0623 - val_loss: 0.0024
# Epoch 19/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0531
# Epoch 19: val_loss improved from 0.00244 to 0.00141, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 57s 2s/step - loss: 0.0531 - val_loss: 0.0014
# Epoch 20/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0476
# Epoch 20: val_loss did not improve from 0.00141
# 37/37 [==============================] - 58s 2s/step - loss: 0.0476 - val_loss: 0.0027
# Epoch 21/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0431
# Epoch 21: val_loss did not improve from 0.00141
# 37/37 [==============================] - 57s 2s/step - loss: 0.0431 - val_loss: 0.0024
# Epoch 22/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0385
# Epoch 22: val_loss did not improve from 0.00141
# 37/37 [==============================] - 56s 2s/step - loss: 0.0385 - val_loss: 0.0024
# Epoch 23/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0341
# Epoch 23: val_loss did not improve from 0.00141
# 37/37 [==============================] - 58s 2s/step - loss: 0.0341 - val_loss: 0.0031
# Epoch 24/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0336
# Epoch 24: val_loss did not improve from 0.00141
# 37/37 [==============================] - 56s 2s/step - loss: 0.0336 - val_loss: 0.0019
# Epoch 25/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0280
# Epoch 25: val_loss did not improve from 0.00141
# 37/37 [==============================] - 59s 2s/step - loss: 0.0280 - val_loss: 0.0019
# Epoch 26/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0247
# Epoch 26: val_loss improved from 0.00141 to 0.00125, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 57s 2s/step - loss: 0.0247 - val_loss: 0.0013
# Epoch 27/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0233
# Epoch 27: val_loss did not improve from 0.00125
# 37/37 [==============================] - 58s 2s/step - loss: 0.0233 - val_loss: 0.0028
# Epoch 28/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0221
# Epoch 28: val_loss did not improve from 0.00125
# 37/37 [==============================] - 55s 2s/step - loss: 0.0221 - val_loss: 0.0018
# Epoch 29/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0191
# Epoch 29: val_loss did not improve from 0.00125
# 37/37 [==============================] - 60s 2s/step - loss: 0.0191 - val_loss: 0.0020
# Epoch 30/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0191
# Epoch 30: val_loss improved from 0.00125 to 0.00115, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 56s 2s/step - loss: 0.0191 - val_loss: 0.0011
# Epoch 31/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0168
# Epoch 31: val_loss did not improve from 0.00115
# 37/37 [==============================] - 58s 2s/step - loss: 0.0168 - val_loss: 0.0017
# Epoch 32/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 32: val_loss did not improve from 0.00115
# 37/37 [==============================] - 65s 2s/step - loss: 0.0162 - val_loss: 0.0012
# Epoch 33/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0160
# Epoch 33: val_loss did not improve from 0.00115
# 37/37 [==============================] - 57s 2s/step - loss: 0.0160 - val_loss: 0.0015
# Epoch 34/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0123
# Epoch 34: val_loss improved from 0.00115 to 0.00092, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 59s 2s/step - loss: 0.0123 - val_loss: 9.2412e-04
# Epoch 35/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 35: val_loss did not improve from 0.00092
# 37/37 [==============================] - 56s 2s/step - loss: 0.0131 - val_loss: 0.0022
# Epoch 36/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0133
# Epoch 36: val_loss did not improve from 0.00092
# 37/37 [==============================] - 58s 2s/step - loss: 0.0133 - val_loss: 0.0013
# Epoch 37/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0125
# Epoch 37: val_loss did not improve from 0.00092
# 37/37 [==============================] - 56s 2s/step - loss: 0.0125 - val_loss: 0.0021
# Epoch 38/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0111
# Epoch 38: val_loss did not improve from 0.00092
# 37/37 [==============================] - 59s 2s/step - loss: 0.0111 - val_loss: 0.0021
# Epoch 39/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0113
# Epoch 39: val_loss did not improve from 0.00092
# 37/37 [==============================] - 59s 2s/step - loss: 0.0113 - val_loss: 0.0012
# Epoch 40/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0098
# Epoch 40: val_loss did not improve from 0.00092
# 37/37 [==============================] - 57s 2s/step - loss: 0.0098 - val_loss: 0.0013
# Epoch 41/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0094
# Epoch 41: val_loss did not improve from 0.00092
# 37/37 [==============================] - 58s 2s/step - loss: 0.0094 - val_loss: 0.0013
# Epoch 42/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0101
# Epoch 42: val_loss improved from 0.00092 to 0.00063, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 56s 2s/step - loss: 0.0101 - val_loss: 6.2908e-04
# Epoch 43/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0089
# Epoch 43: val_loss did not improve from 0.00063
# 37/37 [==============================] - 58s 2s/step - loss: 0.0089 - val_loss: 0.0012
# Epoch 44/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 44: val_loss improved from 0.00063 to 0.00059, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 56s 2s/step - loss: 0.0076 - val_loss: 5.9406e-04
# Epoch 45/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 45: val_loss did not improve from 0.00059
# 37/37 [==============================] - 58s 2s/step - loss: 0.0104 - val_loss: 9.2314e-04
# Epoch 46/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 46: val_loss did not improve from 0.00059
# 37/37 [==============================] - 58s 2s/step - loss: 0.0074 - val_loss: 6.3220e-04
# Epoch 47/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 47: val_loss did not improve from 0.00059
# 37/37 [==============================] - 56s 2s/step - loss: 0.0079 - val_loss: 8.0571e-04
# Epoch 48/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 48: val_loss did not improve from 0.00059
# 37/37 [==============================] - 58s 2s/step - loss: 0.0087 - val_loss: 6.7673e-04
# Epoch 49/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 49: val_loss improved from 0.00059 to 0.00059, saving model to ./best_apple_model.h5
# 37/37 [==============================] - 57s 2s/step - loss: 0.0066 - val_loss: 5.8531e-04
# Epoch 50/50
# 37/37 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 50: val_loss did not improve from 0.00059
# 37/37 [==============================] - 58s 2s/step - loss: 0.0068 - val_loss: 9.8773e-04

# %%
model = load_model('./best_apple_model.h5')
y_apple_pred = model.predict(X_apple_test)

# %%
print(y_apple_pred.shape)
# Out:
# (293, 1)

# %%
y_apple_pred = y_apple_pred.reshape(-1)

# %%
print('Apple,')
print('Mean squared error : ' + str(mean_squared_error(y_apple_test, y_apple_pred)))
print('r2 score : ' + str(r2_score(y_apple_test, y_apple_pred)))
# Out:
# Apple,
# Mean squared error : 0.0005853061378847491
# r2 score : 0.9945362869066848

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize = (20,5))

plt.plot(y_apple_test[100:200])
plt.plot(y_apple_pred[100:200])

plt.xlabel('Time period')
plt.ylabel('Closing prices')
plt.legend(['Actual Price', 'Predicted price'])
plt.title('Closing price comparison for Apple dataset', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Closing price comparison for Apple dataset')

# %% [markdown]
# # Predict for amazon stock data

# %%
model = load_model('./transfer_model.h5')

# %%
for i, layer in enumerate(model.layers) :
    if i < 5 :
        layer.trainable = False

# %%
print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_4 (Sequential)   (None, 300, 256)          135168
#
#  sequential_5 (Sequential)   (None, 300, 128)          164864
#
#  bidirectional_5 (Bidirectio  (None, 128)              98816
#  nal)
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 399,489
# Trainable params: 129
# Non-trainable params: 399,360
# _________________________________________________________________
# None

# %%
X_amazn_train,  X_amazn_test, y_amazn_train, y_amazn_test = train_test_split(X_res_amazn, y_res_amazn, test_size = 0.2, random_state = 1)

# %%
print(X_amazn_train.shape)
print(y_amazn_train.shape)
# Out:
# (1169, 300, 2)
# (1169,)

# %%
print(X_amazn_test.shape)
print(y_amazn_test.shape)
# Out:
# (293, 300, 2)
# (293,)

# %% [markdown]
# ### Train on the last layer

# %%
from keras.callbacks import ModelCheckpoint
checkp = ModelCheckpoint('./best_amazn_model.h5', monitor = 'val_loss', save_best_only = True, verbose = 1)

# %%
history = model.fit(X_amazn_train, y_amazn_train, epochs = 100, batch_size = 32, validation_data = (X_amazn_test, y_amazn_test), callbacks = [checkp])
# Out:
# Epoch 1/100
# 37/37 [==============================] - ETA: 0s - loss: 0.5870
# Epoch 1: val_loss improved from inf to 0.12542, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 69s 2s/step - loss: 0.5870 - val_loss: 0.1254
# Epoch 2/100
# 37/37 [==============================] - ETA: 0s - loss: 0.4242
# Epoch 2: val_loss did not improve from 0.12542
# 37/37 [==============================] - 58s 2s/step - loss: 0.4242 - val_loss: 0.1593
# Epoch 3/100
# 37/37 [==============================] - ETA: 0s - loss: 0.3742
# Epoch 3: val_loss did not improve from 0.12542
# 37/37 [==============================] - 58s 2s/step - loss: 0.3742 - val_loss: 0.1544
# Epoch 4/100
# 37/37 [==============================] - ETA: 0s - loss: 0.3187
# Epoch 4: val_loss did not improve from 0.12542
# 37/37 [==============================] - 59s 2s/step - loss: 0.3187 - val_loss: 0.1398
# Epoch 5/100
# 37/37 [==============================] - ETA: 0s - loss: 0.3014
# Epoch 5: val_loss did not improve from 0.12542
# 37/37 [==============================] - 56s 2s/step - loss: 0.3014 - val_loss: 0.2439
# Epoch 6/100
# 37/37 [==============================] - ETA: 0s - loss: 0.2416
# Epoch 6: val_loss did not improve from 0.12542
# 37/37 [==============================] - 58s 2s/step - loss: 0.2416 - val_loss: 0.2137
# Epoch 7/100
# 37/37 [==============================] - ETA: 0s - loss: 0.2378
# Epoch 7: val_loss did not improve from 0.12542
# 37/37 [==============================] - 56s 2s/step - loss: 0.2378 - val_loss: 0.1376
# Epoch 8/100
# 37/37 [==============================] - ETA: 0s - loss: 0.2132
# Epoch 8: val_loss improved from 0.12542 to 0.09713, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 58s 2s/step - loss: 0.2132 - val_loss: 0.0971
# Epoch 9/100
# 37/37 [==============================] - ETA: 0s - loss: 0.1863
# Epoch 9: val_loss improved from 0.09713 to 0.05294, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 58s 2s/step - loss: 0.1863 - val_loss: 0.0529
# Epoch 10/100
# 37/37 [==============================] - ETA: 0s - loss: 0.1844
# Epoch 10: val_loss did not improve from 0.05294
# 37/37 [==============================] - 56s 2s/step - loss: 0.1844 - val_loss: 0.0890
# Epoch 11/100
# 37/37 [==============================] - ETA: 0s - loss: 0.1280
# Epoch 11: val_loss improved from 0.05294 to 0.02471, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 57s 2s/step - loss: 0.1280 - val_loss: 0.0247
# Epoch 12/100
# 37/37 [==============================] - ETA: 0s - loss: 0.1303
# Epoch 12: val_loss did not improve from 0.02471
# 37/37 [==============================] - 55s 1s/step - loss: 0.1303 - val_loss: 0.0347
# Epoch 13/100
# 37/37 [==============================] - ETA: 0s - loss: 0.1292
# Epoch 13: val_loss improved from 0.02471 to 0.00669, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 57s 2s/step - loss: 0.1292 - val_loss: 0.0067
# Epoch 14/100
# 37/37 [==============================] - ETA: 0s - loss: 0.1058
# Epoch 14: val_loss improved from 0.00669 to 0.00596, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 56s 2s/step - loss: 0.1058 - val_loss: 0.0060
# Epoch 15/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0943
# Epoch 15: val_loss did not improve from 0.00596
# 37/37 [==============================] - 57s 2s/step - loss: 0.0943 - val_loss: 0.0116
# Epoch 16/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0735
# Epoch 16: val_loss improved from 0.00596 to 0.00386, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 57s 2s/step - loss: 0.0735 - val_loss: 0.0039
# Epoch 17/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0777
# Epoch 17: val_loss improved from 0.00386 to 0.00348, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 55s 1s/step - loss: 0.0777 - val_loss: 0.0035
# Epoch 18/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0651
# Epoch 18: val_loss improved from 0.00348 to 0.00169, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 57s 2s/step - loss: 0.0651 - val_loss: 0.0017
# Epoch 19/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0616
# Epoch 19: val_loss did not improve from 0.00169
# 37/37 [==============================] - 55s 1s/step - loss: 0.0616 - val_loss: 0.0026
# Epoch 20/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0551
# Epoch 20: val_loss improved from 0.00169 to 0.00119, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 57s 2s/step - loss: 0.0551 - val_loss: 0.0012
# Epoch 21/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0478
# Epoch 21: val_loss did not improve from 0.00119
# 37/37 [==============================] - 58s 2s/step - loss: 0.0478 - val_loss: 0.0030
# Epoch 22/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0367
# Epoch 22: val_loss improved from 0.00119 to 0.00117, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 57s 2s/step - loss: 0.0367 - val_loss: 0.0012
# Epoch 23/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0375
# Epoch 23: val_loss did not improve from 0.00117
# 37/37 [==============================] - 56s 2s/step - loss: 0.0375 - val_loss: 0.0074
# Epoch 24/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0307
# Epoch 24: val_loss did not improve from 0.00117
# 37/37 [==============================] - 57s 2s/step - loss: 0.0307 - val_loss: 0.0013
# Epoch 25/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0298
# Epoch 25: val_loss did not improve from 0.00117
# 37/37 [==============================] - 57s 2s/step - loss: 0.0298 - val_loss: 0.0023
# Epoch 26/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0273
# Epoch 26: val_loss improved from 0.00117 to 0.00114, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 56s 2s/step - loss: 0.0273 - val_loss: 0.0011
# Epoch 27/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0253
# Epoch 27: val_loss did not improve from 0.00114
# 37/37 [==============================] - 58s 2s/step - loss: 0.0253 - val_loss: 0.0023
# Epoch 28/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0234
# Epoch 28: val_loss improved from 0.00114 to 0.00072, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 56s 2s/step - loss: 0.0234 - val_loss: 7.2327e-04
# Epoch 29/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0197
# Epoch 29: val_loss did not improve from 0.00072
# 37/37 [==============================] - 57s 2s/step - loss: 0.0197 - val_loss: 8.8598e-04
# Epoch 30/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0172
# Epoch 30: val_loss did not improve from 0.00072
# 37/37 [==============================] - 55s 1s/step - loss: 0.0172 - val_loss: 0.0013
# Epoch 31/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0160
# Epoch 31: val_loss did not improve from 0.00072
# 37/37 [==============================] - 58s 2s/step - loss: 0.0160 - val_loss: 0.0019
# Epoch 32/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0145
# Epoch 32: val_loss did not improve from 0.00072
# 37/37 [==============================] - 57s 2s/step - loss: 0.0145 - val_loss: 7.7477e-04
# Epoch 33/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0127
# Epoch 33: val_loss did not improve from 0.00072
# 37/37 [==============================] - 57s 2s/step - loss: 0.0127 - val_loss: 0.0021
# Epoch 34/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0123
# Epoch 34: val_loss did not improve from 0.00072
# 37/37 [==============================] - 58s 2s/step - loss: 0.0123 - val_loss: 0.0015
# Epoch 35/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0109
# Epoch 35: val_loss did not improve from 0.00072
# 37/37 [==============================] - 56s 2s/step - loss: 0.0109 - val_loss: 8.3748e-04
# Epoch 36/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0110
# Epoch 36: val_loss improved from 0.00072 to 0.00067, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 58s 2s/step - loss: 0.0110 - val_loss: 6.6785e-04
# Epoch 37/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0093
# Epoch 37: val_loss did not improve from 0.00067
# 37/37 [==============================] - 56s 2s/step - loss: 0.0093 - val_loss: 0.0025
# Epoch 38/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0094
# Epoch 38: val_loss did not improve from 0.00067
# 37/37 [==============================] - 57s 2s/step - loss: 0.0094 - val_loss: 0.0019
# Epoch 39/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0097
# Epoch 39: val_loss did not improve from 0.00067
# 37/37 [==============================] - 55s 1s/step - loss: 0.0097 - val_loss: 0.0011
# Epoch 40/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 40: val_loss did not improve from 0.00067
# 37/37 [==============================] - 57s 2s/step - loss: 0.0071 - val_loss: 7.7190e-04
# Epoch 41/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 41: val_loss did not improve from 0.00067
# 37/37 [==============================] - 57s 2s/step - loss: 0.0074 - val_loss: 0.0014
# Epoch 42/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0065
# Epoch 42: val_loss did not improve from 0.00067
# 37/37 [==============================] - 55s 1s/step - loss: 0.0065 - val_loss: 0.0011
# Epoch 43/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 43: val_loss did not improve from 0.00067
# 37/37 [==============================] - 57s 2s/step - loss: 0.0062 - val_loss: 9.6624e-04
# Epoch 44/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 44: val_loss did not improve from 0.00067
# 37/37 [==============================] - 55s 1s/step - loss: 0.0057 - val_loss: 8.3078e-04
# Epoch 45/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 45: val_loss did not improve from 0.00067
# 37/37 [==============================] - 57s 2s/step - loss: 0.0060 - val_loss: 0.0040
# Epoch 46/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 46: val_loss did not improve from 0.00067
# 37/37 [==============================] - 55s 1s/step - loss: 0.0063 - val_loss: 0.0014
# Epoch 47/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 47: val_loss improved from 0.00067 to 0.00067, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 56s 2s/step - loss: 0.0072 - val_loss: 6.6757e-04
# Epoch 48/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 48: val_loss did not improve from 0.00067
# 37/37 [==============================] - 57s 2s/step - loss: 0.0060 - val_loss: 0.0012
# Epoch 49/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 49: val_loss did not improve from 0.00067
# 37/37 [==============================] - 56s 2s/step - loss: 0.0041 - val_loss: 8.0202e-04
# Epoch 50/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 50: val_loss did not improve from 0.00067
# 37/37 [==============================] - 57s 2s/step - loss: 0.0037 - val_loss: 6.7057e-04
# Epoch 51/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 51: val_loss did not improve from 0.00067
# 37/37 [==============================] - 55s 1s/step - loss: 0.0039 - val_loss: 8.0318e-04
# Epoch 52/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 52: val_loss did not improve from 0.00067
# 37/37 [==============================] - 57s 2s/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 53/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 53: val_loss did not improve from 0.00067
# 37/37 [==============================] - 57s 2s/step - loss: 0.0055 - val_loss: 8.3864e-04
# Epoch 54/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 54: val_loss improved from 0.00067 to 0.00060, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 55s 1s/step - loss: 0.0042 - val_loss: 6.0241e-04
# Epoch 55/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 55: val_loss did not improve from 0.00060
# 37/37 [==============================] - 57s 2s/step - loss: 0.0053 - val_loss: 8.0600e-04
# Epoch 56/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 56: val_loss did not improve from 0.00060
# 37/37 [==============================] - 55s 1s/step - loss: 0.0039 - val_loss: 7.1042e-04
# Epoch 57/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 57: val_loss did not improve from 0.00060
# 37/37 [==============================] - 57s 2s/step - loss: 0.0040 - val_loss: 0.0013
# Epoch 58/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 58: val_loss did not improve from 0.00060
# 37/37 [==============================] - 55s 1s/step - loss: 0.0037 - val_loss: 0.0015
# Epoch 59/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 59: val_loss did not improve from 0.00060
# 37/37 [==============================] - 57s 2s/step - loss: 0.0039 - val_loss: 8.7612e-04
# Epoch 60/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 60: val_loss did not improve from 0.00060
# 37/37 [==============================] - 55s 1s/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 61/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 61: val_loss did not improve from 0.00060
# 37/37 [==============================] - 57s 2s/step - loss: 0.0029 - val_loss: 6.9202e-04
# Epoch 62/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 62: val_loss did not improve from 0.00060
# 37/37 [==============================] - 57s 2s/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 63/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 63: val_loss improved from 0.00060 to 0.00050, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 55s 1s/step - loss: 0.0039 - val_loss: 5.0469e-04
# Epoch 64/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 64: val_loss did not improve from 0.00050
# 37/37 [==============================] - 57s 2s/step - loss: 0.0041 - val_loss: 6.4234e-04
# Epoch 65/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 65: val_loss did not improve from 0.00050
# 37/37 [==============================] - 55s 1s/step - loss: 0.0039 - val_loss: 0.0022
# Epoch 66/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0040
# Epoch 66: val_loss did not improve from 0.00050
# 37/37 [==============================] - 57s 2s/step - loss: 0.0040 - val_loss: 8.0214e-04
# Epoch 67/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 67: val_loss did not improve from 0.00050
# 37/37 [==============================] - 57s 2s/step - loss: 0.0037 - val_loss: 9.5535e-04
# Epoch 68/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 68: val_loss did not improve from 0.00050
# 37/37 [==============================] - 55s 1s/step - loss: 0.0044 - val_loss: 7.4239e-04
# Epoch 69/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 69: val_loss did not improve from 0.00050
# 37/37 [==============================] - 57s 2s/step - loss: 0.0033 - val_loss: 5.9645e-04
# Epoch 70/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 70: val_loss did not improve from 0.00050
# 37/37 [==============================] - 55s 1s/step - loss: 0.0039 - val_loss: 6.5882e-04
# Epoch 71/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 71: val_loss did not improve from 0.00050
# 37/37 [==============================] - 57s 2s/step - loss: 0.0034 - val_loss: 5.4720e-04
# Epoch 72/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 72: val_loss did not improve from 0.00050
# 37/37 [==============================] - 55s 1s/step - loss: 0.0035 - val_loss: 7.5354e-04
# Epoch 73/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 73: val_loss did not improve from 0.00050
# 37/37 [==============================] - 57s 2s/step - loss: 0.0028 - val_loss: 9.3060e-04
# Epoch 74/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 74: val_loss did not improve from 0.00050
# 37/37 [==============================] - 57s 2s/step - loss: 0.0031 - val_loss: 6.6359e-04
# Epoch 75/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 75: val_loss did not improve from 0.00050
# 37/37 [==============================] - 55s 1s/step - loss: 0.0032 - val_loss: 7.2255e-04
# Epoch 76/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 76: val_loss did not improve from 0.00050
# 37/37 [==============================] - 56s 2s/step - loss: 0.0033 - val_loss: 5.3511e-04
# Epoch 77/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 77: val_loss did not improve from 0.00050
# 37/37 [==============================] - 55s 1s/step - loss: 0.0038 - val_loss: 0.0022
# Epoch 78/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 78: val_loss did not improve from 0.00050
# 37/37 [==============================] - 57s 2s/step - loss: 0.0036 - val_loss: 0.0011
# Epoch 79/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 79: val_loss did not improve from 0.00050
# 37/37 [==============================] - 57s 2s/step - loss: 0.0037 - val_loss: 0.0013
# Epoch 80/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 80: val_loss did not improve from 0.00050
# 37/37 [==============================] - 55s 1s/step - loss: 0.0036 - val_loss: 7.4829e-04
# Epoch 81/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 81: val_loss did not improve from 0.00050
# 37/37 [==============================] - 56s 2s/step - loss: 0.0030 - val_loss: 6.2798e-04
# Epoch 82/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 82: val_loss did not improve from 0.00050
# 37/37 [==============================] - 55s 1s/step - loss: 0.0041 - val_loss: 7.0980e-04
# Epoch 83/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 83: val_loss improved from 0.00050 to 0.00045, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 56s 2s/step - loss: 0.0042 - val_loss: 4.5474e-04
# Epoch 84/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 84: val_loss did not improve from 0.00045
# 37/37 [==============================] - 57s 2s/step - loss: 0.0039 - val_loss: 6.5052e-04
# Epoch 85/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 85: val_loss did not improve from 0.00045
# 37/37 [==============================] - 55s 1s/step - loss: 0.0035 - val_loss: 8.1710e-04
# Epoch 86/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 86: val_loss did not improve from 0.00045
# 37/37 [==============================] - 57s 2s/step - loss: 0.0032 - val_loss: 4.7551e-04
# Epoch 87/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 87: val_loss did not improve from 0.00045
# 37/37 [==============================] - 58s 2s/step - loss: 0.0038 - val_loss: 5.6295e-04
# Epoch 88/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 88: val_loss did not improve from 0.00045
# 37/37 [==============================] - 58s 2s/step - loss: 0.0036 - val_loss: 0.0011
# Epoch 89/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 89: val_loss did not improve from 0.00045
# 37/37 [==============================] - 58s 2s/step - loss: 0.0037 - val_loss: 5.8553e-04
# Epoch 90/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 90: val_loss did not improve from 0.00045
# 37/37 [==============================] - 56s 2s/step - loss: 0.0030 - val_loss: 0.0019
# Epoch 91/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 91: val_loss did not improve from 0.00045
# 37/37 [==============================] - 58s 2s/step - loss: 0.0037 - val_loss: 5.9473e-04
# Epoch 92/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 92: val_loss did not improve from 0.00045
# 37/37 [==============================] - 56s 2s/step - loss: 0.0033 - val_loss: 6.8350e-04
# Epoch 93/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 93: val_loss did not improve from 0.00045
# 37/37 [==============================] - 58s 2s/step - loss: 0.0038 - val_loss: 0.0018
# Epoch 94/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 94: val_loss did not improve from 0.00045
# 37/37 [==============================] - 58s 2s/step - loss: 0.0038 - val_loss: 8.2007e-04
# Epoch 95/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 95: val_loss did not improve from 0.00045
# 37/37 [==============================] - 56s 2s/step - loss: 0.0037 - val_loss: 9.4125e-04
# Epoch 96/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 96: val_loss did not improve from 0.00045
# 37/37 [==============================] - 58s 2s/step - loss: 0.0034 - val_loss: 5.6584e-04
# Epoch 97/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 97: val_loss improved from 0.00045 to 0.00041, saving model to ./best_amazn_model.h5
# 37/37 [==============================] - 56s 2s/step - loss: 0.0034 - val_loss: 4.1402e-04
# Epoch 98/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 98: val_loss did not improve from 0.00041
# 37/37 [==============================] - 58s 2s/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 99/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 99: val_loss did not improve from 0.00041
# 37/37 [==============================] - 58s 2s/step - loss: 0.0033 - val_loss: 6.3460e-04
# Epoch 100/100
# 37/37 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 100: val_loss did not improve from 0.00041
# 37/37 [==============================] - 56s 2s/step - loss: 0.0048 - val_loss: 6.0878e-04

# %% [markdown]
# ### Use the 'best_amazn_model.h5' for prediction

# %%
model = load_model('./best_amazn_model.h5')

# %%
y_amazn_pred = model.predict(X_amazn_test)

# %%
print(y_amazn_pred.shape)
# Out:
# (293, 1)

# %%
y_amazn_pred = y_amazn_pred.reshape(-1)

# %%
print('Mean_sqaured_error : ' + str(mean_squared_error(y_amazn_test, y_amazn_pred)))
print('r2_score : ' + str(r2_score(y_amazn_test, y_amazn_pred)))
# Out:
# Mean_sqaured_error : 0.00041402261970610425
# r2_score : 0.9934924508608425

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize = (20,5))

plt.plot(y_amazn_test[100:200])
plt.plot(y_amazn_pred[100:200])

plt.xlabel('Time period')
plt.ylabel('Closing prices')
plt.legend(['Actual Price', 'Predicted price'])
plt.title('Closing price comparison for Amazon dataset', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Closing price comparison for Amazon dataset')
